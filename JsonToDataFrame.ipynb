# %%
import json, os
import pandas as pd
from pandas.io.json import json_normalize

# %%
path_to_json = 'howest_dataset/'
dataset= pd.DataFrame()
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]

for json_file in json_files:
    json_file=path_to_json+json_file
    with open(json_file) as train_file:
        dict_train = json.load(train_file)
    file_df=pd.DataFrame.from_dict(pd.json_normalize(dict_train), orient='columns')
    dataset=dataset.append(file_df)

# %%
dataset.head(1000)
# Out:
#   language client_reference  \
# 0    fr_BE     ZSN202006957
# 0    fr_BE     ZSN202010883
# 0    nl_BE     NSN202011807
# 0    fr_BE   ZSN20201297601
# 0    nl_BE     NSN202013139
# 0    nl_BE       C202028773
# 0    nl_BE       C202034750
# 0    nl_BE       C302005692
# 0    fr_BE   NSN21200147702
# 0    nl_BE       C202027039
#
#                                         mail_subject  \
# 0                MISSION_ASSIGNEMENT: ZSN20200695701
# 0                MISSION_ASSIGNEMENT: ZSN20201088301
# 0                MISSION_ASSIGNEMENT: NSN20201180701
# 0                MISSION_ASSIGNEMENT: ZSN20201297601
# 0                MISSION_ASSIGNEMENT: NSN20201313901
# 0  Betreft het schadegeval nr. *C202028773* van 2...
# 0  Betreft het schadegeval nr. *C202034750* van 2...
# 0  Betreft het schadegeval nr. *C302005692* van 0...
# 0                MISSION_ASSIGNEMENT: NSN21200147702
# 0  Betreft het schadegeval nr. *C202027039* van 1...
#
#                                         mail_content           party_id  \
# 0  <anon> annexe nous vous transmettons un docume...  21955048183443173
# 0  <anon> annexe nous vous transmettons un docume...  21955048183443173
# 0  in bijlage <anon> wij een document met betrekk...  21955048183443173
# 0  <anon> annexe nous vous transmettons un docume...  21955048183443173
# 0  in bijlage <anon> wij een document met betrekk...  21955048183443173
# 0  <anon> <anon> <anon> <anon> <anon> <anon> <ano...  21955048183443174
# 0  <anon> <anon> <anon> <anon> <anon> <anon> <ano...  21955048183443174
# 0  <anon> <anon> <anon> <anon> <anon> <anon> <ano...  21955048183443174
# 0  en annexe nous vous transmettons un document c...  21955048183443173
# 0  <anon> <anon> <anon> <anon> <anon> <anon> <ano...  21955048183443174
#
#          party_type            unit_id organization  \
# 0  nonNaturalPerson               None      Allianz
# 0  nonNaturalPerson               None      Allianz
# 0  nonNaturalPerson  24206847997116432      Allianz
# 0  nonNaturalPerson  24206847997116432      Allianz
# 0  nonNaturalPerson  24206847997116432      Allianz
# 0  nonNaturalPerson  24206847997116445    P&V Groep
# 0  nonNaturalPerson               None    P&V Groep
# 0  nonNaturalPerson  24206847997116443    P&V Groep
# 0  nonNaturalPerson  24206847997116432      Allianz
# 0  nonNaturalPerson  24206847997116445    P&V Groep
#
#                     from_mail                comments  \
# 0      NoReplyECNM@allianz.be
# 0      NoReplyECNM@allianz.be
# 0      NoReplyECNM@allianz.be               Beheer
# 0      NoReplyECNM@allianz.be               Beheer
# 0      NoReplyECNM@allianz.be               Beheer
# 0  claims-brand-ANT@vivium.be  Claims Brand Antwerpen
# 0  claims-brand-ANT@vivium.be
# 0     claims-BA-ANT@vivium.be     Claims BA Antwerpen
# 0      NoReplyECNM@allianz.be               Beheer
# 0  claims-brand-ANT@vivium.be  Claims Brand Antwerpen
#
#                                          attachments labels.assignment_type  \
# 0  [{'filename': 'MISSION_ASSIGNEMENT.pdf', 'cont...             Unilateral
# 0  [{'filename': 'MISSION_ASSIGNEMENT.pdf', 'cont...             Unilateral
# 0  [{'filename': 'MISSION_ASSIGNEMENT.pdf', 'cont...             Unilateral
# 0  [{'filename': 'MISSION_ASSIGNEMENT.pdf', 'cont...             Unilateral
# 0  [{'filename': 'courtier envoie le devis et con...              Bilateral
# 0  [{'filename': 'Foto's van de schade.pdf', 'con...             Unilateral
# 0  [{'filename': 'Polis Grimonprez.pdf', 'content...             Unilateral
# 0  [{'filename': 'DOCUMENT.pdf', 'content': 'hist...              Bilateral
# 0  [{'filename': 'MISSION_ASSIGNEMENT.pdf', 'cont...             Unilateral
# 0  [{'filename': 'v pr bestek opruim bomen 3560 E...             Unilateral
#
#   labels.case_type labels.sub_case_type labels.damage_type
# 0         Property                 Fire        WaterDamage
# 0         Property                 Fire        WaterDamage
# 0         Property                 Fire              Storm
# 0         Property                 Fire        WaterDamage
# 0         Property                 Fire          Collision
# 0         Property                 Fire          Collision
# 0         Property                 Fire        WaterDamage
# 0        Liability           Operations        WaterDamage
# 0         Property                 Fire        WaterDamage
# 0         Property                 Fire              Storm
